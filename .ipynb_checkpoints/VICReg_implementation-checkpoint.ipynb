# %%
import numpy as np 
import torch 
import matplotlib.pyplot as plt 
from scipy.stats import skew
from optuna import Trial
import optuna
from torch import optim
import time
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE
from sklearn.datasets import make_blobs
import pandas as pd 
from sklearn.cluster import KMeans

# %%
class Encoder(torch.nn.Module): 
    def __init__(self,**kwargs):
        super(Encoder,self).__init__()
        self.__dict__.update(kwargs)
        self.linear = torch.nn.Linear(in_features = self.in_features, out_features=self.out_features)
        
    def forward(self,x): 
        x = self.linear(x)
        return x.relu()
      
class Projector(torch.nn.Module): 
    def __init__(self,**kwargs):
        super(Projector,self).__init__()
        self.__dict__.update(kwargs) 
        self.linear = torch.nn.Linear(in_features = self.in_features, out_features=self.out_features)
        
    def forward(self,x): 
        x = self.linear(x)
        return x.relu()
    
    
class EncoderProjectorModel(torch.nn.Module): 
    def __init__(self,**kwargs): 
        super(EncoderProjectorModel,self).__init__()
        self.__dict__.update(kwargs)
        self.encoder1 = Encoder(in_features = self.in_encoder_features, out_features = self.out_encoder_features)
        self.encoder2 = Encoder(in_features = self.in_encoder_features, out_features = self.out_encoder_features)
        self.projector1 = Projector(in_features = self.in_projector_features, out_features = self.out_projector_features)
        self.projector2 = Projector(in_features = self.in_projector_features, out_features = self.out_projector_features)
        
    def forward(self,x): 
        encoded_1 = self.encoder1(x)
        encoded_2 = self.encoder2(x)
        projected_1 = self.projector1(encoded_1)
        projected_2 = self.projector2(encoded_2)
        return encoded_1,encoded_2,projected_1,projected_2
        
class VICLoss(): 
    def __init__(self,**kwargs): 
        self.__dict__.update(kwargs) 
    
    def variance_loss(self,x): 
        def func(x,gamma,epsilon):
            return max([0,gamma - torch.sqrt(x.var()+epsilon)])
        return sum([func(x[:,dim],self.gamma,self.epsilon) for dim in range(x.shape[1])])
        
    def covariance_loss(self,x): 
        cov = torch.tensor(np.cov(x.detach().numpy()))
        ind = np.diag_indices(cov.shape[0])
        cov[ind[0],ind[1]] = torch.zeros(cov.shape[0]).double()
        return (cov**2).sum()/cov.shape[0]
        
    def distance_loss(self,x,y): 
        loss = torch.nn.MSELoss() 
        return loss(x,y)
    
    def __call__(self,x,y): 
        return self.lam*self.distance_loss(x,y)+self.mu*(self.variance_loss(x)+self.variance_loss(y)
                                                 )+self.nu*(self.covariance_loss(x)+self.covariance_loss(y))
    
class Training(): 
    def __init__(self,**kwargs): 
        self.__dict__.update(kwargs)
         
    def metrics(self): 
        pass
    
    def sample_batch(self,batch_size): 
        indices = np.random.choice(np.arange(self.data.shape[0]),batch_size, replace = False)
        return self.data[indices,:]

    def training(self,trial):
        
        # Fixed parameters
        in_encoder_features = self.config["Encoder"]["in_features"]
        out_encoder_features = self.config["Encoder"]["out_features"]
        in_projector_features = self.config["Projector"]["in_features"]
        gamma = self.config["Model"]["loss"]["gamma"]
        epsilon = self.config["Model"]["loss"]["epsilon"] 
        nu = self.config["Model"]["loss"]["nu"] 
        epochs = self.config["Model"]["epochs"]
        
        # To optimize
        if not hasattr(self,'study'): 
            out_projector_features = trial.suggest_int("projector_out_features",*self.config["Projector"]["out_features"])
            lam = trial.suggest_int("lam",*self.config["Model"]["loss"]["lambda"])
            mu = trial.suggest_int("mu",*self.config["Model"]["loss"]["mu"])
            lr = trial.suggest_uniform("lr",*self.config["Optimizer"]["lr"])
            beta1 = trial.suggest_uniform("beta1",*self.config["Optimizer"]["beta1"])
            beta2 = trial.suggest_uniform("beta2",*self.config["Optimizer"]["beta2"])
            batch_size = trial.suggest_int("batch_size",*self.config["Model"]["batch_size"])
 
        else:
            assert not trial
            out_projector_features = self.study.best_params["projector_out_features"]
            lam = self.study.best_params["lam"]
            mu = self.study.best_params["mu"]
            lr = self.study.best_params["lr"]
            beta1 = self.study.best_params["beta1"]
            beta2 = self.study.best_params["beta2"]
            batch_size = self.study.best_params["batch_size"]
            
        # Instanciate the model
        model = self.model(in_encoder_features = in_encoder_features, 
                          out_encoder_features = out_encoder_features, 
                          in_projector_features = in_projector_features, 
                          out_projector_features = out_projector_features)
        
        if not trial: 
            print("N params = ",sum([p.numel() for p in model.parameters()]))
    
        # Define the loss
        criterion = VICLoss(gamma = gamma, epsilon = epsilon, lam = lam, mu = mu, nu = nu)
        
        # Define the optimizer
        optimizer = optim.Adam(model.parameters(), lr=lr, betas = (beta1,beta2))
        
        # Training loop
        losses = list()
        for epoch in range(epochs):
            
            batches = self.sample_batch(batch_size)
            optimizer.zero_grad()
            encoded_1,encoded_2,projected_1,projected_2 = model(batches)
            loss = criterion(projected_1,projected_2)
            loss.backward()
            optimizer.step()

            losses+=[loss]
                
            
        if trial:
            return min(losses)
        else: 
            self.trained_model = model
            return losses
            
class Optimize(): 
    def __init__(self,**kwargs): 
        self.__dict__.update(kwargs)
        
    def monitor_execution_time(func): 
        def wrapper(self,**kwargs):
            start = time.time()
            func(self,**kwargs)
            print("Elapsed time: ", round(time.time()-start,2), "seconds")
        return wrapper 
        
    @monitor_execution_time
    def optimize(self,data): 
        study = optuna.create_study(direction = "minimize")
        training = Training(config = self.config, model = self.model, data = data)
        study.optimize(training.training, n_trials=100)
        training.study = study
        self.training = training 
    
    def training_on_best_params(self,data):
        # Train on data (could be new data)
        self.training.data = data
        self.losses = self.training.training(trial = False)
        self.trained_model = self.training.trained_model
        
    def predict(self,data): 
        return self.trained_model(data)

class Evaluate(): 
    def __init__(self,**kwargs): 
        self.__dict__.update(kwargs)
        
    def get_mse(self,encoded_1,encoded_2): 
        loss = torch.nn.MSELoss()
        return loss(encoded_1,encoded_2)
    
    def make_pca(self,x,n_components = 2): 
        pca = PCA(n_components)
        pca_components = pd.DataFrame(pca.fit_transform(x),
              columns = [f'PC{n}' for n in range(1,n_components+1)]) 
        return pca_components

    def make_umap(self): 
        pass 
    
    def make_tsne(self,x,n_components = 2): 
        tsne = TSNE(n_components)
        tsne_components = pd.DataFrame(tsne.fit_transform(x),
              columns = [f'TSNE{n}' for n in range(1,n_components+1)]) 
        return tsne_components
    
    def compute_kmeans(self,x,n_clusters): 
        kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(x)
        return kmeans.labels_
    
    def get_silhouette_coefficient(self,x,y):
        return silhouette_score(x,y)
    
    def compare_clustering(self,data,encoded_1,encoded_2,labels,n_kmeans_clusters = None):

        if not labels:
            assert n_kmeans_clusters != None
            labels = self.compute_kmeans(x,n_kmeans_clusters)
            
        datasets = {"Original data":data, "Embeddings 1":encoded_1,"Embeddings 2":encoded_2}
        f,ax = plt.subplots(3,2,figsize = (20,15))
        ax = ax.flatten()
        it = 0 
        
        for name,dataset in datasets.items(): 
            dataset = dataset.detach().numpy()
            pca_components = self.make_pca(dataset)
            tsne_components = self.make_tsne(dataset)
            data_silhouette = self.get_silhouette_coefficient(dataset,labels)
            pca_silhouette = self.get_silhouette_coefficient(pca_components,labels)
            tsne_silhouette = self.get_silhouette_coefficient(tsne_components,labels)
            
            ax[it].scatter(data = pca_components, x = "PC1", y = "PC2",c = labels)
            ax[it+1].scatter(data = tsne_components, x = "TSNE1", y = "TSNE2", c = labels)
            ax[it].set(title = f" Dataset {name} - PCA components - pca silhouette = {pca_silhouette} -\n data silhouette = {data_silhouette} - ratio = {pca_silhouette/data_silhouette}")
            ax[it+1].set(title = f"Dataset {name} - TSNE components - tsne silhouette = {tsne_silhouette} -\n data silhouette = {data_silhouette} - ratio = {tsne_silhouette/data_silhouette}")
            it+=2

# %%
in_features = 1000
out_features = 50
n_samples = 100 
data,labels = make_blobs(n_samples=n_samples, n_features=in_features, centers=10, cluster_std=3)
data = torch.tensor(data).float()

config = {"Encoder":{"in_features":in_features,"out_features":out_features},
          "Projector":{"in_features":out_features,"out_features":(50,200,1)}, 
          "Model":{"loss":{"gamma":1,"epsilon":0.01,"lambda":(1,25,1),"mu":(1,25,1),"nu":1},
                   "batch_size":(5,20,1),"epochs":100},
          "Optimizer":{"lr":(0.001,0.1),"beta1":(0.9,0.99),"beta2":(0.96,0.99)}, 
         }

optimize = Optimize(model = EncoderProjectorModel, config = config)
optimize.optimize(data = data)
optimize.training_on_best_params(data = data)
embeddings_1, embeddings_2, _, _ = optimize.predict(data = data)
# Out:
# [I 2022-02-03 00:57:09,163] A new study created in memory with name: no-name-ab31e56e-8995-405e-8388-4c56fe377ff1
# [I 2022-02-03 00:57:10,240] Trial 0 finished with value: 1729.6784941031217 and parameters: {'projector_out_features': 119, 'lam': 21, 'mu': 25, 'lr': 0.047603138888358584, 'beta1': 0.9430172647972177, 'beta2': 0.9828770126596812, 'batch_size': 20}. Best is trial 0 with value: 1729.6784941031217.
# [I 2022-02-03 00:57:10,886] Trial 1 finished with value: 462.4406888342607 and parameters: {'projector_out_features': 65, 'lam': 5, 'mu': 10, 'lr': 0.04518702835615998, 'beta1': 0.9065115661169894, 'beta2': 0.9833839797199821, 'batch_size': 16}. Best is trial 1 with value: 462.4406888342607.
# [I 2022-02-03 00:57:11,696] Trial 2 finished with value: 506.7490920322823 and parameters: {'projector_out_features': 131, 'lam': 8, 'mu': 10, 'lr': 0.004037075449908046, 'beta1': 0.9736102529047208, 'beta2': 0.9743054888199113, 'batch_size': 19}. Best is trial 1 with value: 462.4406888342607.
# [I 2022-02-03 00:57:12,543] Trial 3 finished with value: 889.8285416868941 and parameters: {'projector_out_features': 85, 'lam': 13, 'mu': 14, 'lr': 0.07905054826458617, 'beta1': 0.9027895938275045, 'beta2': 0.9648015764336598, 'batch_size': 11}. Best is trial 1 with value: 462.4406888342607.
# [I 2022-02-03 00:57:13,988] Trial 4 finished with value: 132.88097207141124 and parameters: {'projector_out_features': 175, 'lam': 2, 'mu': 1, 'lr': 0.04971364024716265, 'beta1': 0.9409810392498488, 'beta2': 0.9737029580794115, 'batch_size': 18}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:15,100] Trial 5 finished with value: 1127.5744804566323 and parameters: {'projector_out_features': 180, 'lam': 13, 'mu': 19, 'lr': 0.018883396230478418, 'beta1': 0.9032818203322154, 'beta2': 0.9631331972357383, 'batch_size': 17}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:16,621] Trial 6 finished with value: 1629.4725103336025 and parameters: {'projector_out_features': 170, 'lam': 23, 'mu': 13, 'lr': 0.09791298614314525, 'beta1': 0.9832223835629477, 'beta2': 0.9819158564688195, 'batch_size': 15}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:17,568] Trial 7 finished with value: 850.7691640892432 and parameters: {'projector_out_features': 98, 'lam': 7, 'mu': 10, 'lr': 0.043147130704865665, 'beta1': 0.9622022167444724, 'beta2': 0.9773958197397599, 'batch_size': 8}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:18,900] Trial 8 finished with value: 932.9551897723176 and parameters: {'projector_out_features': 143, 'lam': 22, 'mu': 7, 'lr': 0.0958556203446678, 'beta1': 0.9863927985383171, 'beta2': 0.9720313367540789, 'batch_size': 5}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:19,799] Trial 9 finished with value: 1135.0232499689741 and parameters: {'projector_out_features': 127, 'lam': 16, 'mu': 20, 'lr': 0.02715158097858957, 'beta1': 0.9505979724751435, 'beta2': 0.9712042678348523, 'batch_size': 20}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:21,464] Trial 10 finished with value: 149.59423197091496 and parameters: {'projector_out_features': 199, 'lam': 1, 'mu': 1, 'lr': 0.0692601015508837, 'beta1': 0.9277908414588345, 'beta2': 0.9893258210766644, 'batch_size': 12}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:23,122] Trial 11 finished with value: 148.27272747799708 and parameters: {'projector_out_features': 200, 'lam': 1, 'mu': 1, 'lr': 0.06960723881623883, 'beta1': 0.933327436376931, 'beta2': 0.9877233204197576, 'batch_size': 12}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:24,824] Trial 12 finished with value: 153.95483641369742 and parameters: {'projector_out_features': 200, 'lam': 1, 'mu': 1, 'lr': 0.06851910563773833, 'beta1': 0.9283298631948294, 'beta2': 0.9890382265655041, 'batch_size': 14}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:26,266] Trial 13 finished with value: 640.0955574694888 and parameters: {'projector_out_features': 162, 'lam': 3, 'mu': 5, 'lr': 0.06472254860013857, 'beta1': 0.9274573498113117, 'beta2': 0.9677543438271939, 'batch_size': 10}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:27,816] Trial 14 finished with value: 632.9662471988036 and parameters: {'projector_out_features': 157, 'lam': 8, 'mu': 5, 'lr': 0.05993195271972892, 'beta1': 0.9426586929105445, 'beta2': 0.9784836279606588, 'batch_size': 8}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:29,545] Trial 15 finished with value: 429.6300004455141 and parameters: {'projector_out_features': 188, 'lam': 5, 'mu': 3, 'lr': 0.08561931777845597, 'beta1': 0.920845401948266, 'beta2': 0.9683696183712491, 'batch_size': 14}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:31,060] Trial 16 finished with value: 723.082910953 and parameters: {'projector_out_features': 179, 'lam': 17, 'mu': 6, 'lr': 0.0341873171127306, 'beta1': 0.9574534613687424, 'beta2': 0.9863290641136486, 'batch_size': 18}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:32,554] Trial 17 finished with value: 133.65425450930167 and parameters: {'projector_out_features': 151, 'lam': 10, 'mu': 1, 'lr': 0.056730673031804804, 'beta1': 0.9369752561373468, 'beta2': 0.9774653417801423, 'batch_size': 13}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:33,806] Trial 18 finished with value: 1484.4138903904454 and parameters: {'projector_out_features': 148, 'lam': 10, 'mu': 16, 'lr': 0.05527008277646061, 'beta1': 0.9667614126838626, 'beta2': 0.9789246571712774, 'batch_size': 17}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:35,041] Trial 19 finished with value: 735.3680034682561 and parameters: {'projector_out_features': 109, 'lam': 11, 'mu': 8, 'lr': 0.03132207656142136, 'beta1': 0.9167992032784329, 'beta2': 0.974803455510502, 'batch_size': 9}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:36,408] Trial 20 finished with value: 357.7874186387409 and parameters: {'projector_out_features': 145, 'lam': 17, 'mu': 3, 'lr': 0.014944605377513631, 'beta1': 0.937984697028996, 'beta2': 0.9601947466968036, 'batch_size': 6}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:38,060] Trial 21 finished with value: 360.97429081772736 and parameters: {'projector_out_features': 172, 'lam': 4, 'mu': 3, 'lr': 0.07640021537227279, 'beta1': 0.9359620246372174, 'beta2': 0.9858617136390325, 'batch_size': 13}. Best is trial 4 with value: 132.88097207141124.
# [I 2022-02-03 00:57:39,718] Trial 22 finished with value: 114.09724981249619 and parameters: {'projector_out_features': 191, 'lam': 1, 'mu': 1, 'lr': 0.05308269897192292, 'beta1': 0.9526453158750173, 'beta2': 0.9799740978915856, 'batch_size': 13}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:41,105] Trial 23 finished with value: 466.14715990375714 and parameters: {'projector_out_features': 159, 'lam': 6, 'mu': 4, 'lr': 0.05477388566829169, 'beta1': 0.9514464544203647, 'beta2': 0.9804312317104407, 'batch_size': 15}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:42,586] Trial 24 finished with value: 144.00309425045228 and parameters: {'projector_out_features': 186, 'lam': 3, 'mu': 1, 'lr': 0.03566951125195125, 'beta1': 0.9498952384794503, 'beta2': 0.9765289769094038, 'batch_size': 13}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:44,089] Trial 25 finished with value: 1010.2803437064963 and parameters: {'projector_out_features': 166, 'lam': 25, 'mu': 8, 'lr': 0.039598199573629186, 'beta1': 0.9560440538494132, 'beta2': 0.9726100770783233, 'batch_size': 11}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:45,311] Trial 26 finished with value: 315.03990258086054 and parameters: {'projector_out_features': 135, 'lam': 10, 'mu': 3, 'lr': 0.04984504964264467, 'beta1': 0.9714561537084527, 'beta2': 0.9698366364181654, 'batch_size': 15}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:46,510] Trial 27 finished with value: 393.7753247507681 and parameters: {'projector_out_features': 152, 'lam': 2, 'mu': 5, 'lr': 0.06101857026801969, 'beta1': 0.9141338992310758, 'beta2': 0.9750087193920298, 'batch_size': 18}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:47,957] Trial 28 finished with value: 682.4774894410773 and parameters: {'projector_out_features': 183, 'lam': 4, 'mu': 8, 'lr': 0.05351143660907778, 'beta1': 0.9474519008887582, 'beta2': 0.9802139482808161, 'batch_size': 16}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:48,936] Trial 29 finished with value: 1815.0344779628492 and parameters: {'projector_out_features': 117, 'lam': 15, 'mu': 25, 'lr': 0.04716194846047615, 'beta1': 0.9375262975912189, 'beta2': 0.9844169340361232, 'batch_size': 20}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:50,322] Trial 30 finished with value: 265.9075791051761 and parameters: {'projector_out_features': 172, 'lam': 19, 'mu': 2, 'lr': 0.02470980191109727, 'beta1': 0.9425918385566029, 'beta2': 0.9817010764958874, 'batch_size': 11}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:51,847] Trial 31 finished with value: 142.094549614999 and parameters: {'projector_out_features': 186, 'lam': 3, 'mu': 1, 'lr': 0.034320995263996575, 'beta1': 0.9557993238992545, 'beta2': 0.9769324243152395, 'batch_size': 14}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:53,306] Trial 32 finished with value: 548.4336007282484 and parameters: {'projector_out_features': 191, 'lam': 3, 'mu': 4, 'lr': 0.04287549893692448, 'beta1': 0.959595908824266, 'beta2': 0.9766531610986084, 'batch_size': 14}. Best is trial 22 with value: 114.09724981249619.
# [I 2022-02-03 00:57:53,946] Trial 33 finished with value: 95.79810451636116 and parameters: {'projector_out_features': 52, 'lam': 6, 'mu': 2, 'lr': 0.057403253138028236, 'beta1': 0.9418892246148957, 'beta2': 0.9735505937551401, 'batch_size': 16}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:54,578] Trial 34 finished with value: 272.7916130162444 and parameters: {'projector_out_features': 52, 'lam': 8, 'mu': 6, 'lr': 0.05729771182200454, 'beta1': 0.943907042574125, 'beta2': 0.9738278235540834, 'batch_size': 17}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:55,541] Trial 35 finished with value: 122.9628542703457 and parameters: {'projector_out_features': 81, 'lam': 6, 'mu': 2, 'lr': 0.04990776774448704, 'beta1': 0.9311909832958519, 'beta2': 0.9704543345318997, 'batch_size': 16}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:56,292] Trial 36 finished with value: 610.4418891592148 and parameters: {'projector_out_features': 75, 'lam': 6, 'mu': 11, 'lr': 0.050030542922743254, 'beta1': 0.9326107709489321, 'beta2': 0.966078963566545, 'batch_size': 19}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:56,937] Trial 37 finished with value: 112.35374792555562 and parameters: {'projector_out_features': 53, 'lam': 5, 'mu': 3, 'lr': 0.07783786328078382, 'beta1': 0.9098670418268415, 'beta2': 0.9700197330441234, 'batch_size': 16}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:57,602] Trial 38 finished with value: 157.65812019079178 and parameters: {'projector_out_features': 52, 'lam': 6, 'mu': 4, 'lr': 0.0786606093238249, 'beta1': 0.9089768762603856, 'beta2': 0.9701774516529218, 'batch_size': 16}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:58,297] Trial 39 finished with value: 450.02729697731286 and parameters: {'projector_out_features': 64, 'lam': 12, 'mu': 10, 'lr': 0.08995715213061993, 'beta1': 0.9000077016215087, 'beta2': 0.9648910232847181, 'batch_size': 16}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:57:59,295] Trial 40 finished with value: 509.7169822727763 and parameters: {'projector_out_features': 91, 'lam': 8, 'mu': 7, 'lr': 0.07340057909403505, 'beta1': 0.9235436061244466, 'beta2': 0.9682932565652514, 'batch_size': 15}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:00,008] Trial 41 finished with value: 114.93838326026508 and parameters: {'projector_out_features': 63, 'lam': 5, 'mu': 2, 'lr': 0.08438153149289904, 'beta1': 0.9110951879701765, 'beta2': 0.9726445371260878, 'batch_size': 18}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:00,749] Trial 42 finished with value: 99.086643473137 and parameters: {'projector_out_features': 63, 'lam': 5, 'mu': 2, 'lr': 0.08922426648945164, 'beta1': 0.9092347145318888, 'beta2': 0.9726450316779907, 'batch_size': 19}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:01,499] Trial 43 finished with value: 108.64747464514109 and parameters: {'projector_out_features': 63, 'lam': 4, 'mu': 2, 'lr': 0.0838289484768741, 'beta1': 0.9075532534825967, 'beta2': 0.9727749871722604, 'batch_size': 19}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:02,274] Trial 44 finished with value: 153.3351385043465 and parameters: {'projector_out_features': 72, 'lam': 4, 'mu': 3, 'lr': 0.09490306936692174, 'beta1': 0.9051002082739645, 'beta2': 0.9751888291784032, 'batch_size': 19}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:03,045] Trial 45 finished with value: 646.3485649073804 and parameters: {'projector_out_features': 59, 'lam': 2, 'mu': 16, 'lr': 0.08426090003716398, 'beta1': 0.9158063786671329, 'beta2': 0.9715925260917223, 'batch_size': 19}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:03,927] Trial 46 finished with value: 324.056668033151 and parameters: {'projector_out_features': 72, 'lam': 7, 'mu': 6, 'lr': 0.09926082965572612, 'beta1': 0.9081953962119838, 'beta2': 0.9734384280635808, 'batch_size': 17}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:04,571] Trial 47 finished with value: 146.98691104171456 and parameters: {'projector_out_features': 56, 'lam': 1, 'mu': 4, 'lr': 0.0923451498331189, 'beta1': 0.9198609296952646, 'beta2': 0.9694540512852459, 'batch_size': 18}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:05,525] Trial 48 finished with value: 148.05186686418259 and parameters: {'projector_out_features': 100, 'lam': 5, 'mu': 2, 'lr': 0.06509353224217321, 'beta1': 0.9818050010758488, 'beta2': 0.9671404302274287, 'batch_size': 20}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:06,280] Trial 49 finished with value: 1104.315739589343 and parameters: {'projector_out_features': 81, 'lam': 2, 'mu': 24, 'lr': 0.07315505907187339, 'beta1': 0.9129017922991883, 'beta2': 0.9712592311970196, 'batch_size': 20}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:07,016] Trial 50 finished with value: 563.665448387428 and parameters: {'projector_out_features': 70, 'lam': 9, 'mu': 12, 'lr': 0.08872355346393997, 'beta1': 0.9037643767018346, 'beta2': 0.975606943310407, 'batch_size': 19}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:07,726] Trial 51 finished with value: 106.20471243339054 and parameters: {'projector_out_features': 64, 'lam': 4, 'mu': 2, 'lr': 0.08231105019142752, 'beta1': 0.910784910550558, 'beta2': 0.9728461997076512, 'batch_size': 17}. Best is trial 33 with value: 95.79810451636116.
# [I 2022-02-03 00:58:08,492] Trial 52 finished with value: 88.66408223397114 and parameters: {'projector_out_features': 59, 'lam': 4, 'mu': 2, 'lr': 0.08287440910021998, 'beta1': 0.919194728561055, 'beta2': 0.973432954857344, 'batch_size': 17}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:09,153] Trial 53 finished with value: 220.14838327576814 and parameters: {'projector_out_features': 50, 'lam': 7, 'mu': 5, 'lr': 0.0799711967508865, 'beta1': 0.9238682281184216, 'beta2': 0.9733652269568352, 'batch_size': 17}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:09,922] Trial 54 finished with value: 88.78878287034266 and parameters: {'projector_out_features': 59, 'lam': 4, 'mu': 2, 'lr': 0.087275146292231, 'beta1': 0.9180698771407648, 'beta2': 0.9721687504329212, 'batch_size': 17}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:10,656] Trial 55 finished with value: 102.60313678706365 and parameters: {'projector_out_features': 60, 'lam': 3, 'mu': 2, 'lr': 0.08196617401943886, 'beta1': 0.9190808396994761, 'beta2': 0.9721540844540826, 'batch_size': 18}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:11,386] Trial 56 finished with value: 202.46349681762453 and parameters: {'projector_out_features': 68, 'lam': 3, 'mu': 4, 'lr': 0.08928712778301341, 'beta1': 0.9189930306745383, 'beta2': 0.9743456283057834, 'batch_size': 18}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:12,205] Trial 57 finished with value: 283.9654651126494 and parameters: {'projector_out_features': 59, 'lam': 7, 'mu': 6, 'lr': 0.09471775641621384, 'beta1': 0.9239252975971173, 'beta2': 0.971495461252207, 'batch_size': 17}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:13,043] Trial 58 finished with value: 110.55298153679661 and parameters: {'projector_out_features': 78, 'lam': 2, 'mu': 2, 'lr': 0.08039449106254994, 'beta1': 0.9005898966814365, 'beta2': 0.9781461598356562, 'batch_size': 18}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:13,893] Trial 59 finished with value: 343.0597943037919 and parameters: {'projector_out_features': 88, 'lam': 4, 'mu': 5, 'lr': 0.07012482728352276, 'beta1': 0.9176123048187315, 'beta2': 0.9758527508508601, 'batch_size': 17}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:14,600] Trial 60 finished with value: 918.6487621415339 and parameters: {'projector_out_features': 59, 'lam': 9, 'mu': 20, 'lr': 0.08731821679372338, 'beta1': 0.928950527653811, 'beta2': 0.9685539632889376, 'batch_size': 18}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:15,315] Trial 61 finished with value: 95.47791153872826 and parameters: {'projector_out_features': 63, 'lam': 4, 'mu': 2, 'lr': 0.08255090234971094, 'beta1': 0.9061826443771007, 'beta2': 0.9725543461528342, 'batch_size': 19}. Best is trial 52 with value: 88.66408223397114.
# [I 2022-02-03 00:58:16,120] Trial 62 finished with value: 60.220599702185496 and parameters: {'projector_out_features': 67, 'lam': 5, 'mu': 1, 'lr': 0.07465601629057765, 'beta1': 0.9126555076542726, 'beta2': 0.9719730995655059, 'batch_size': 20}. Best is trial 62 with value: 60.220599702185496.
# [I 2022-02-03 00:58:16,882] Trial 63 finished with value: 58.330547317351325 and parameters: {'projector_out_features': 67, 'lam': 5, 'mu': 1, 'lr': 0.07397592920160072, 'beta1': 0.9133293028443167, 'beta2': 0.9718727342742453, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:17,616] Trial 64 finished with value: 59.876808206081094 and parameters: {'projector_out_features': 68, 'lam': 5, 'mu': 1, 'lr': 0.07383951127335463, 'beta1': 0.9137523427938146, 'beta2': 0.9707590412149761, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:18,584] Trial 65 finished with value: 74.43615318422576 and parameters: {'projector_out_features': 93, 'lam': 7, 'mu': 1, 'lr': 0.07392154532827665, 'beta1': 0.9124522381501589, 'beta2': 0.968993674337691, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:19,677] Trial 66 finished with value: 80.0539068094739 and parameters: {'projector_out_features': 97, 'lam': 7, 'mu': 1, 'lr': 0.07330267158073929, 'beta1': 0.9144887610586971, 'beta2': 0.9666399556794774, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:20,820] Trial 67 finished with value: 89.31495662711177 and parameters: {'projector_out_features': 96, 'lam': 9, 'mu': 1, 'lr': 0.06555530122545905, 'beta1': 0.9141930915480306, 'beta2': 0.9625863240292144, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:21,907] Trial 68 finished with value: 82.81383834087887 and parameters: {'projector_out_features': 103, 'lam': 7, 'mu': 1, 'lr': 0.07440603800935859, 'beta1': 0.9213026467937477, 'beta2': 0.9658058185464246, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:23,007] Trial 69 finished with value: 90.11119853935374 and parameters: {'projector_out_features': 108, 'lam': 7, 'mu': 1, 'lr': 0.0754276494202531, 'beta1': 0.9222007637968617, 'beta2': 0.9663358948429825, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:24,219] Trial 70 finished with value: 103.4988186626628 and parameters: {'projector_out_features': 104, 'lam': 14, 'mu': 1, 'lr': 0.07021518275551605, 'beta1': 0.9128342142957842, 'beta2': 0.9640852453250642, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:25,287] Trial 71 finished with value: 257.0125953039445 and parameters: {'projector_out_features': 113, 'lam': 8, 'mu': 3, 'lr': 0.07484173928557444, 'beta1': 0.925724455181363, 'beta2': 0.9690718511640509, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:26,261] Trial 72 finished with value: 76.97198822905843 and parameters: {'projector_out_features': 93, 'lam': 6, 'mu': 1, 'lr': 0.06748755305918236, 'beta1': 0.9150568742028591, 'beta2': 0.9672185724317951, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:27,247] Trial 73 finished with value: 78.72692721909486 and parameters: {'projector_out_features': 92, 'lam': 6, 'mu': 1, 'lr': 0.06290709125902877, 'beta1': 0.9150801496441692, 'beta2': 0.9672221252832163, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:28,273] Trial 74 finished with value: 82.28918917330623 and parameters: {'projector_out_features': 93, 'lam': 11, 'mu': 1, 'lr': 0.06803394195983233, 'beta1': 0.9152737894002584, 'beta2': 0.9671725385093661, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:29,291] Trial 75 finished with value: 225.0403446649113 and parameters: {'projector_out_features': 94, 'lam': 12, 'mu': 3, 'lr': 0.06212783783910547, 'beta1': 0.9151445958022012, 'beta2': 0.967323896934096, 'batch_size': 19}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:30,207] Trial 76 finished with value: 84.47756198939493 and parameters: {'projector_out_features': 85, 'lam': 10, 'mu': 1, 'lr': 0.06724589146128399, 'beta1': 0.9038291055471234, 'beta2': 0.9634061003500076, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:31,026] Trial 77 finished with value: 306.4079021542227 and parameters: {'projector_out_features': 84, 'lam': 6, 'mu': 4, 'lr': 0.0710968341394715, 'beta1': 0.9125373948262413, 'beta2': 0.9707001354854338, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:32,148] Trial 78 finished with value: 86.55689170396316 and parameters: {'projector_out_features': 91, 'lam': 11, 'mu': 1, 'lr': 0.05978219866460679, 'beta1': 0.906636381881341, 'beta2': 0.9619584447029165, 'batch_size': 19}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:33,350] Trial 79 finished with value: 274.6982729075999 and parameters: {'projector_out_features': 126, 'lam': 6, 'mu': 3, 'lr': 0.06687016553086646, 'beta1': 0.916061447072552, 'beta2': 0.9668201097335821, 'batch_size': 19}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:34,177] Trial 80 finished with value: 241.81787443281277 and parameters: {'projector_out_features': 77, 'lam': 9, 'mu': 4, 'lr': 0.06308519523717329, 'beta1': 0.9256099069801871, 'beta2': 0.9649918268923514, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:35,268] Trial 81 finished with value: 84.42697837807265 and parameters: {'projector_out_features': 101, 'lam': 8, 'mu': 1, 'lr': 0.07260288466863218, 'beta1': 0.9117659444508848, 'beta2': 0.9656455462226253, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:36,499] Trial 82 finished with value: 105.40391737915452 and parameters: {'projector_out_features': 120, 'lam': 7, 'mu': 1, 'lr': 0.06875574818449237, 'beta1': 0.9162008524143354, 'beta2': 0.9679769010256664, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:37,536] Trial 83 finished with value: 226.0640100661928 and parameters: {'projector_out_features': 104, 'lam': 5, 'mu': 3, 'lr': 0.07587630321493781, 'beta1': 0.9217526071804826, 'beta2': 0.969196290529179, 'batch_size': 19}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:38,583] Trial 84 finished with value: 82.94605025752122 and parameters: {'projector_out_features': 90, 'lam': 8, 'mu': 1, 'lr': 0.07749237530650938, 'beta1': 0.9144512123117593, 'beta2': 0.9656243765633288, 'batch_size': 20}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:39,866] Trial 85 finished with value: 109.98402087534828 and parameters: {'projector_out_features': 134, 'lam': 7, 'mu': 1, 'lr': 0.07325463220576825, 'beta1': 0.9084581087828109, 'beta2': 0.9678262348987283, 'batch_size': 19}. Best is trial 63 with value: 58.330547317351325.
# [I 2022-02-03 00:58:40,552] Trial 86 finished with value: 32.44683124268403 and parameters: {'projector_out_features': 94, 'lam': 6, 'mu': 3, 'lr': 0.0010417443565500367, 'beta1': 0.9105687397376326, 'beta2': 0.9688332520268997, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:41,247] Trial 87 finished with value: 81.6369285074883 and parameters: {'projector_out_features': 96, 'lam': 5, 'mu': 3, 'lr': 0.01090693820435628, 'beta1': 0.9105922758547378, 'beta2': 0.9706167233111808, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:41,819] Trial 88 finished with value: 53.55125202008134 and parameters: {'projector_out_features': 81, 'lam': 5, 'mu': 3, 'lr': 0.003979386793340921, 'beta1': 0.9106026357188578, 'beta2': 0.9706110135618374, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:42,381] Trial 89 finished with value: 34.839637470125155 and parameters: {'projector_out_features': 82, 'lam': 6, 'mu': 3, 'lr': 0.0012338544279742996, 'beta1': 0.9014468008342993, 'beta2': 0.9689924767664392, 'batch_size': 6}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:42,964] Trial 90 finished with value: 67.78879527869748 and parameters: {'projector_out_features': 87, 'lam': 6, 'mu': 4, 'lr': 0.006741420131601279, 'beta1': 0.9016178232124453, 'beta2': 0.9687329941066666, 'batch_size': 5}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:43,499] Trial 91 finished with value: 78.83266426547196 and parameters: {'projector_out_features': 86, 'lam': 6, 'mu': 5, 'lr': 0.002461236351201818, 'beta1': 0.9049301151990011, 'beta2': 0.9687482826793313, 'batch_size': 5}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:44,290] Trial 92 finished with value: 55.016217481642784 and parameters: {'projector_out_features': 74, 'lam': 5, 'mu': 4, 'lr': 0.006835712257576098, 'beta1': 0.9014567666315872, 'beta2': 0.9695480215095098, 'batch_size': 6}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:45,085] Trial 93 finished with value: 123.1085439223292 and parameters: {'projector_out_features': 80, 'lam': 5, 'mu': 7, 'lr': 0.008003759263543558, 'beta1': 0.9003679714696713, 'beta2': 0.9698274208336526, 'batch_size': 6}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:45,706] Trial 94 finished with value: 60.09997397085968 and parameters: {'projector_out_features': 74, 'lam': 5, 'mu': 4, 'lr': 0.006025844481960447, 'beta1': 0.9014856619873897, 'beta2': 0.9708463166932256, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:46,252] Trial 95 finished with value: 57.67930183667159 and parameters: {'projector_out_features': 73, 'lam': 5, 'mu': 4, 'lr': 0.0057761043107571524, 'beta1': 0.9029434468219467, 'beta2': 0.9711241930682, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:46,769] Trial 96 finished with value: 146.3321535366768 and parameters: {'projector_out_features': 68, 'lam': 5, 'mu': 6, 'lr': 0.0062789351047693, 'beta1': 0.9024603684724464, 'beta2': 0.9709340120430936, 'batch_size': 8}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:47,442] Trial 97 finished with value: 373.38260698175253 and parameters: {'projector_out_features': 74, 'lam': 3, 'mu': 7, 'lr': 0.015276714570094198, 'beta1': 0.9022833723453592, 'beta2': 0.9716089679677351, 'batch_size': 6}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:47,997] Trial 98 finished with value: 190.21949416681613 and parameters: {'projector_out_features': 67, 'lam': 2, 'mu': 4, 'lr': 0.004733022710304001, 'beta1': 0.9059771707586954, 'beta2': 0.9699025521238944, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# [I 2022-02-03 00:58:48,533] Trial 99 finished with value: 52.749519334443725 and parameters: {'projector_out_features': 74, 'lam': 3, 'mu': 5, 'lr': 0.0010930934978965992, 'beta1': 0.9025708189920212, 'beta2': 0.9696440068001754, 'batch_size': 7}. Best is trial 86 with value: 32.44683124268403.
# Elapsed time:  99.37 seconds
# N params =  109688

# %%
evaluate = Evaluate()
evaluate.compare_clustering(data = data, encoded_1 = embeddings_1, encoded_2 = embeddings_2, labels = labels)
